# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Alif Maulana Kesi**
#
# **2611533028**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="Images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algoritma dan Pemograman yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan Pengenalan Python, VSCODE, dan Koneksi ke GITHUB.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep  Pengenalan Python, VSCODE, dan Koneksi ke GITHUB pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python merupakan salah satu bahasa pemrograman yang mudah dipelajari dan banyak digunakan. Dalam proses penulisan program, Visual Studio Code (VS Code) dapat digunakan sebagai aplikasi untuk membuat dan menjalankan kode. Selain itu, GitHub berfungsi sebagai platform untuk menyimpan, mengelola, dan membagikan proyek pemrograman secara online. Oleh karena itu, pengenalan Python, VS Code, dan koneksi dengan GitHub penting untuk membantu memahami dasar-dasar pengembangan program.
#
# ## 1.2 Tujuan
# 1. Mengenal dasar - dasar bahasa pemograman python
# 2. Memahami pengginaan VS CODE sebagai aplikasi untuk menulis dan menjalankan program
# 3. Mengetahui cara menghubungkan dan menggunakan GitHub untuk menyimpan dan menggunakan proyek
#
# ## 1.3 Manfaat
# 1.	Membantu meningkatkan pemahaman tentang dasar-dasar pemrograman.
# 2.	Memudahkan proses pembuatan dan pengembangan program menggunakan VS Code.
# 3.	Memudahkan penyimpanan, pengelolaan, dan pembagian proyek melalui GitHub.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Mengenal Dasar-Dasar Bahasa Pemrograman Python
#
# Python merupakan salah satu bahasa pemrograman yang banyak digunakan karena memiliki sintaks yang sederhana dan mudah dipahami. Dalam pembelajaran dasar, pengguna dapat mengenal cara menulis kode, menggunakan variabel, tipe data, serta membuat program sederhana. Python dapat digunakan dalam berbagai bidang, seperti pengembangan aplikasi, pengolahan data, dan kecerdasan buatan.
#
# 2. Memahami Penggunaan Visual Studio Code (VS Code)
#
# Visual Studio Code atau VS Code merupakan aplikasi yang digunakan untuk menulis dan mengedit kode program. VS Code menyediakan berbagai fitur yang dapat memudahkan pengguna dalam membuat program, seperti penulisan kode yang lebih terstruktur, ekstensi, dan terminal. Dengan menggunakan VS Code, proses pembuatan dan menjalankan program Python menjadi lebih mudah.
#
# 3. Mengetahui Cara Menghubungkan dan Menggunakan GitHub
#
# GitHub merupakan platform yang digunakan untuk menyimpan dan mengelola proyek pemrograman secara online. GitHub memungkinkan pengguna untuk menyimpan kode, mencatat perubahan, serta membagikan proyek kepada orang lain. Dengan menghubungkan proyek dari VS Code ke GitHub, pengguna dapat mengelola dan menyimpan hasil pekerjaan dengan lebih aman dan terorganisir.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "NamaKelas_NIM"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""
print("Hello World")
print()
print("Program ini mengahasilkan")
print(" Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + " dibuat oleh Alif Maulana Kesi_2611533028")

# %% [markdown]
# **Penjelasan :**
# 1.1.	Bagian pertama, bagian ini adalah teks yang diapit tiga tanda kutip. Karena tidak disimpan ke variabel atau dipanggil, Python menganggapnya sebagai komentar dan tidak ikut dieksekusi/dicetak. Fungsinya hanya sebagai catatan/dokumentasi program (judul tugas, keterangan pertemuan, dll).
# 2.	Bagian kedua, bagian ini berisi deretan print sederhana. Pada baris pertama, print() mencetak teks Hello World. Pada baris kedua, kode print mencetak baris kosong. Pada baris ketiga, print() mencetak teks Program ini menghasilkan. Pada baris keempat, print() mencetak teks Empat baris output. Pada baris terakhir, berisi karakter escape \\, yang di dalam string Python setiap \\ mewakili satu karakter \ sehingga hasil cetaknya adalah: / \\ // \\\\ /// \\\\\\
# 3.	Bagian ketiga, bagian ini berisi print() dengan penggabungan string (concatenation). Tanda + menggabungkan tiga potongan string jadi satu kalimat utuh. \n di tengah string berarti “pindah ke baris baru” saat dicetak. Kode ditulis menjadi dua baris fisik hanya untuk kerapian, Python tetap membacanya sebagai satu baris print() karena tanda kurungnya belum ditutup di baris pertama.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang mudah dipelajari dan digunakan untuk membuat berbagai program. Dalam proses pemrograman, Visual Studio Code (VS Code) berfungsi sebagai aplikasi yang membantu pengguna dalam menulis, mengedit, dan menjalankan kode program.
#
# Dalam konteks pemrograman, GitHub dimanfaatkan sebagai platform untuk menyimpan, mengelola, dan membagikan proyek secara online, sehingga proses pengembangan program menjadi lebih terorganisir dan memudahkan pengguna dalam mengelola perubahan pada kode.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
#
# 1. Python
#
# Dicoding Indonesia. (2026). Memulai pemrograman dengan Python. Diakses dari https://www.dicoding.com/academies/86
#
# Python Software Foundation. (2026). Tutorial Python. Diakses dari https://docs.python.org/id/3.10/tutorial/index.html
#
# Petani Kode. (2026). Tutorial dasar pemrograman Python. Diakses dari https://www.petanikode.com/tutorial/python/
#
# Duniailkom. (2026). Tutorial belajar bahasa pemrograman Python untuk pemula. Diakses dari https://www.duniailkom.com/tutorial-belajar-bahasa-pemrograman-python-untuk-pemula/
#
# 2. Visual Studio Code
#
# ION Network. (2024). Visual Studio Code adalah: Pengertian, fitur, fungsi. Diakses dari https://blog.ionnetwork.co.id/visual-studio-code-adalah-pengertian-fitur-fungsi/
#
# Sekawan Media. (2026). Mengenal Visual Studio Code dan 6 fiturnya yang bermanfaat. Diakses dari https://www.sekawanmedia.co.id/blog/visual-studio-code/
#
# dCloud. (2026). Kenali VSCode: Pengertian, cara kerja, dan fitur-fiturnya. Diakses dari https://dcloud.co.id/blog/kenali-vscode-pengertian-cara-kerja-dan-fiturnya.html
#
# 3. GitHub
#
# Dicoding Indonesia. (2021). Apa itu GitHub? Berikut cara menggunakannya. Diakses dari https://www.dicoding.com/blog/apa-itu-github/
#
# Dicoding Indonesia. (2026). Apa perbedaan Git dan GitHub? Berikut penjelasannya. Diakses dari https://www.dicoding.com/blog/perbedaan-git-dan-github/
#
# Dicoding Indonesia. (2026). Belajar dasar Git dengan GitHub. Diakses dari https://www.dicoding.com/academies/317-belajar-dasar-git-dengan-github
#
# Qwords. (2026). Mengenal apa itu GitHub dan cara menggunakannya. Diakses dari https://www.qwords.com/blog/apa-itu-github/
