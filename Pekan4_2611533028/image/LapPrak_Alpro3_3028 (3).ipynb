# %% [markdown]
# <h4 align="center" style="height:1123px;"><b>
#
#     LAPORAN PRAKTIKUM
#
#     ALGORITMA & PEMOGRAMAN
#
#     “Conditonal pada Python”
#
#     Disusun Oleh :
#
#     Alif Maulana Kesi
#
#     2611533028
#
#     Dosen Pengampu:
#
#     Dr. Ir  Wahyudi, S.T., M.T
#
#     Asisten Praktikum:
#
#     Sherly Sukmadira
#
# <br>
#
#  <img src="logo_unand.png" width="200">
#
# <br>
#
#     FAKULTAS TEKNOLOGI INFORMASI
#
#     DEPARTEMEN INFORMATIKA
#
#     UNIVERSITAS ANDALAS
#
#     2026
#
# </b></h4>
# </div>

# %% [markdown]
# ---
#
#
# <h2 align="center">KATA PENGANTAR</h2>
# Puji syukur kehadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya laporan praktikum yang berjudul “Operasi pada Python” ini dapat diselesaikan dengan baik. Laporan ini disusun untuk memenuhi salah satu tugas praktikum serta membantu memahami penggunaan berbagai operasi dalam bahasa pemrograman Python.
#
# Dalam praktikum ini, penulis mempelajari beberapa jenis operasi yang terdapat pada Python, seperti operasi aritmatika, perbandingan, logika, penugasan, serta operasi lainnya yang dapat digunakan dalam pembuatan program. Dengan adanya praktikum ini, diharapkan penulis dapat memahami cara kerja operator dan menerapkannya dalam program sederhana.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan agar laporan berikutnya dapat menjadi lebih baik. Semoga laporan ini dapat memberikan manfaat bagi penulis maupun pembaca dalam mempelajari dasar-dasar pemrograman Python.
#
#
#
# Padang, 2026
# <br>
# <br>
# <br>
# Alif Maulana Kesi
# 2611533028

# %% [markdown]
# ---
#
# <h1 align="center">BAB I<br>PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
# Dalam pemrograman komputer, hampir seluruh persoalan dunia nyata melibatkan pengambilan keputusan. Sebuah program tidak selalu berjalan secara linear dari baris pertama hingga baris terakhir, tetapi seringkali harus memilih salah satu dari beberapa kemungkinan tindakan berdasarkan kondisi tertentu. Kemampuan inilah yang difasilitasi oleh struktur kontrol percabangan (conditional statement).
# Python menyediakan beberapa bentuk struktur percabangan, mulai dari if sederhana, if-else, if-elif-else berjenjang (nested), beberapa blok if yang berdiri sendiri (multi-if), hingga struktur match case yang diperkenalkan pada Python 3.10 sebagai alternatif yang lebih ringkas dan mudah dibaca dibandingkan rangkaian if-elif yang panjang.
# Untuk memahami penerapan konsep tersebut secara langsung, disusun enam buah program latihan yang masing-masing mendemonstrasikan satu bentuk percabangan berbeda, yaitu program kelulusan IPK dengan if tunggal, kelulusan IPK dengan if-else, konversi angka bulan dengan match case, penentuan kelayakan berkendara dengan multi-if, perhitungan diskon belanja dengan multi-if yang bersifat akumulatif, serta konversi nilai angka menjadi huruf dengan if-elif berjenjang. Laporan ini disusun untuk mendokumentasikan proses, hasil, dan analisis dari keenam program tersebut.
#
# ## 1.2 Tujuan
# 1. 	Memahami konsep dasar struktur kontrol percabangan (conditional) dalam bahasa pemrograman Python.
# 2.	Mengimplementasikan pernyataan if tunggal untuk mengeksekusi kode berdasarkan satu syarat.
# 3.	Mengimplementasikan pernyataan if-else untuk menangani dua kemungkinan hasil yang saling eksklusif.
# 4.	Mengimplementasikan pernyataan match case sebagai alternatif dari rangkaian if-elif yang panjang.
# 5.	Membedakan penerapan multi-if (beberapa blok if independen) dengan if-elif berjenjang (nested), termasuk dampaknya terhadap hasil akhir program.
# 6.	Melatih penggunaan fungsi input() beserta konversi tipe data (int, float) dan manipulasi string (strip, lower, pengindeksan) dalam pengambilan keputusan.
#
#
# ## 1.3 Manfaat
# 1. 	Mahasiswa mampu menentukan struktur percabangan yang tepat sesuai kebutuhan logika suatu persoalan.
# 2.	Mahasiswa memahami perbedaan mendasar antara struktur yang saling eksklusif (elif) dengan struktur yang independen (multi-if), sehingga tidak salah menerapkan keduanya pada kasus nyata.
# 3.	Mahasiswa memperoleh keterampilan praktis dalam menyusun program interaktif berbasis input pengguna.
# 4.	Hasil praktikum dapat dijadikan referensi dasar untuk mempelajari struktur kontrol yang lebih kompleks, seperti perulangan (loop) dan fungsi, pada tahap pembelajaran selanjutnya.
# 5.	Melatih kemampuan analisis alur eksekusi (tracing) program, yaitu kemampuan memprediksi keluaran program berdasarkan nilai masukan tertentu

# %% [markdown]
# <h1 align="center">BAB II<br>PEMBAHASAN</h1>
#
# ## 2.1 Dasar Teori
#
# 2.1 Pernyataan If
# Pernyataan if merupakan bentuk paling dasar dari struktur percabangan. Blok kode di bawah if hanya akan dieksekusi apabila ekspresi kondisional yang diuji bernilai True. Apabila kondisi bernilai False, seluruh baris pada blok tersebut dilewati tanpa ada tindakan apa pun.
#
# 2..2 Pernyataan If-Else
# Struktur if-else menambahkan jalur alternatif yang akan dijalankan apabila kondisi pada if bernilai False. Dengan demikian, program akan selalu mengeksekusi salah satu dari dua blok yang tersedia, sehingga selalu ada keluaran yang dihasilkan.
#
# 2.3 Pernyataan If-Elif-Else Berjenjang (Nested)
# Struktur if-elif-else digunakan ketika terdapat lebih dari dua kemungkinan hasil yang saling eksklusif. Python akan mengevaluasi setiap kondisi secara berurutan dari atas ke bawah, dan begitu satu kondisi terpenuhi, blok tersebut dijalankan lalu seluruh proses pengecekan dihentikan sehingga kondisi-kondisi berikutnya tidak lagi diperiksa.
#
# 2.4 Multi-If (Blok If Independen)
# Berbeda dengan elif, penulisan beberapa blok if secara terpisah menyebabkan Python mengevaluasi setiap blok tersebut secara independen, tanpa saling menghentikan proses pengecekan satu sama lain. Apabila kondisi-kondisi yang diuji saling eksklusif, hasil akhirnya hanya satu blok yang aktif. Namun apabila kondisi-kondisi tersebut dapat bernilai True secara bersamaan, maka lebih dari satu blok dapat dijalankan sekaligus, seperti pada kasus akumulasi diskon belanja.
#
# 2.5 Pernyataan Match Case
# Pernyataan match, yang diperkenalkan pada Python 3.10 melalui PEP 634, memungkinkan pencocokan sebuah nilai terhadap beberapa pola (pattern) secara berurutan menggunakan blok case. Struktur ini menjadi alternatif yang lebih terstruktur dibandingkan rangkaian if-elif yang panjang, khususnya ketika terdapat banyak nilai tetap (fixed values) yang perlu dibandingkan. Blok case _ berfungsi sebagai pola wildcard yang menangani nilai apa pun yang tidak cocok dengan pola-pola sebelumnya.
#
# 2.6 Fungsi Input dan Konversi Tipe Data
# Seluruh program pada praktikum ini menggunakan fungsi input() untuk menerima data dari pengguna, yang secara default menghasilkan tipe data string. Oleh karena itu, diperlukan fungsi konversi seperti int() untuk bilangan bulat dan float() untuk bilangan desimal agar nilai tersebut dapat dibandingkan secara numerik di dalam ekspresi kondisional. Selain itu, metode string seperti .strip(), .lower(), dan pengindeksan [0] digunakan untuk menormalkan variasi masukan pengguna, misalnya perbedaan huruf besar-kecil atau spasi berlebih, sebelum dibandingkan dalam kondisi.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program if1_2611533028

# %%
# Buat file dengan nama if1_2611533028.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_3028 = float(input("Input IPK Anda = "))

if ipk_3028 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK",str(ipk_3028))

print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.99
# Program Selesai

# %% [markdown]
# Penjelasan:
# 1. input(...) menampilkan teks "Input IPK Anda = " dan menunggu pengguna mengetik sesuatu. Hasil dari input() selalu berupa teks/string.
# 2. float(...) mengubah teks tersebut menjadi angka desimal (contoh: "3.5" jadi 3.5).
# Hasilnya disimpan ke variabel ipk_3028.
# 3. if mengecek apakah nilai ipk_3028 lebih besar dari 2.75.
# 4. Jika kondisi ini benar (True), baris di dalamnya (yang menjorok/indented) dijalankan → mencetak pesan kelulusan. str(ipk_3028) mengubah angka kembali jadi teks agar bisa digabung saat dicetak.
# 5. Jika kondisi salah (False), baris di dalam if dilewati begitu saja, tidak ada pesan apa pun yang tercetak.
# 6. "print("Program Selesai")" artinya menampilkan hasil dari program ini.

# %% [markdown]
# ### 2.2.2 Program if2_2611533028

# %%
# Buat file dengan nama if2_2611533028.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_3028 = float(input("Input IPK Anda = "))

if ipk_3028 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK",str(ipk_3028))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.99
# Program Selesai

# %% [markdown]
# Penjelasan:
# 1. input(...) menampilkan teks "Input IPK Anda = " dan menunggu pengguna mengetik sesuatu. Hasil dari input() selalu berupa teks/string.
# 2. float(...) mengubah teks tersebut menjadi angka desimal (contoh: "3.5" jadi 3.5).
# Hasilnya disimpan ke variabel ipk_3028.
# 3. if mengecek apakah nilai ipk_3028 lebih besar dari 2.75.
# 4. Jika kondisi ini benar (True), baris di dalamnya (yang menjorok/indented) dijalankan → mencetak pesan kelulusan. str(ipk_3028) mengubah angka kembali jadi teks agar bisa digabung saat dicetak.
# 5. Jika kondisi salah (False), baris di dalam if dilewati begitu saja, tidak ada pesan apa pun yang tercetak.
# 6. else berarti "jika tidak" — dijalankan hanya jika kondisi if di atasnya salah.
# 7. Jadi sekarang ada dua kemungkinan hasil yang saling eksklusif (tidak mungkin dua-duanya tercetak):
# IPK > 2.75 → cetak "Lulus Sangat Memuaskan"
# IPK ≤ 2.75 → cetak "Tidak Lulus"
# 8. "print("Program Selesai")" artinya menampilkan hasil dari program ini.

# %% [markdown]
# ### 2.2.3 Program match_case1_2611533028

# %%
# Buat file dengan nama match_case1_2611533028.py
# Buat program untuk match case 
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_3028 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_3028:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# Desember

# %% [markdown]
# Penjelasan:
# 1. Input diubah jadi bilangan bulat (int) karena bulan berupa angka utuh (1, 2, 3, ...).
# 2. match mengambil nilai bulan_3028, lalu Python mencocokkannya dari atas ke bawah dengan tiap case.
# Begitu ditemukan case yang nilainya sama persis dengan bulan_3028, blok di bawah case itu dijalankan, dan pencocokan berhenti (tidak lanjut cek case berikutnya).
# 3. Contoh: kalau bulan_3028 = 3, Python cek case 1 (tidak cocok) → case 2 (tidak cocok) → case 3 (cocok!) → cetak "Maret" → selesai.
# 4. case _ adalah kasus default/wildcard — artinya "kalau tidak cocok dengan semua case di atas". Jadi kalau pengguna input misalnya 13 atau 0, akan masuk ke sini dan cetak "Angka tidak valid".

# %% [markdown]
# ### 2.2.4 Program multi_if1_2611533028

# %%
# Buat file dengan nama multi_if1_2611533028.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_3028 = int(input("Input Umur Anda = "))
sim_3028 = input("Apakah Anda Sudah Punya SIM C (y/t): ")[0]

if umur_3028 >= 17 and sim_3028 == "y":
    print("Anda Sudah dewasa dan boleh bawa motor")

if umur_3028 >= 17 and sim_3028 != "y":
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")

if umur_3028 < 17 and sim_3028 != "y":
    print("Anda Belum Cukup Umur punya SIM")

if umur_3028 < 17 and sim_3028 == "y":
    print("Anda Belum Cukup Umur bawa Motor")
# Out:
# Anda Sudah dewasa tetapi tidak boleh bawa motor

# %% [markdown]
# Penjelasan:
# 1. umur_3028: input umur, diubah jadi angka bulat.
# 2. sim_3028: input jawaban ya/tidak. Tambahan [0] mengambil karakter pertama saja dari teks yang diketik. Misalnya kalau user ketik "ya", maka [0] mengambil huruf "y" saja. Ini trik supaya user boleh ketik "y", "ya", "yes" — asal huruf pertamanya "y", tetap terbaca sama.
# 3. ada 4 blok if yang terpisah, bukan if/elif/elif/elif. Ini yang disebut multi-if.
# and berarti kedua syarat harus benar sekaligus baru blok tersebut dijalankan.
# 4. Karena masing-masing ditulis sebagai if sendiri (bukan elif), Python mengecek keempat-empatnya satu per satu, tidak berhenti walau salah satu sudah cocok. Bedanya dengan elif: kalau pakai elif, begitu satu syarat cocok, yang lain otomatis dilewati.
# 5. Namun karena keempat syarat di sini saling eksklusif (tidak mungkin dua kondisi sekaligus benar — umur tidak mungkin ≥17 dan <17 bersamaan), pada akhirnya cuma satu pesan yang akan tercetak meski caranya multi-if.

# %% [markdown]
# <div style="font-size: 18px3028
#
# Penjelasan:
#
#
# </div>

# %% [markdown]
# ### 2.2.5 Program multi_if2_2611533028

# %%
# Buat file dengan nama multi_if2_2611533028.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: total_belanja_1234
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_3028 = float(input("Masukkan total belanja (Rp): "))

# Input status member (mengecek apakah user mengetik 'y atau 'ya')
input_member_3028 = input("Apakah Anda Member? (y/t): ").strip().lower()
is_member_3028 = input_member_3028 in ["y", "ya"]

# Input satus kode promo (mengecek apakah user mengetik 'y atau 'ya')
input_promo_3028 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_3028 = input_promo_3028 in ["y", "ya"]

total_diskon_persen_3028 = 0

# Multi-IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_3028 > 1000000:
    total_diskon_persen_3028 += 10  # Diskon belanja besar 

if is_member_3028:
    total_diskon_persen_3028 += 5  # Diskon member

if kode_promo_valid_3028:
    total_diskon_persen_3028 += 15  # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_3028 = total_belanja_3028 * (total_diskon_persen_3028 / 100)
total_bayar_3028 = total_belanja_3028 - nominal_diskon_3028

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon  : {total_diskon_persen_3028}% (Rp {nominal_diskon_3028:,.0f})")
print(f"Total Bayar   : Rp {total_bayar_3028:,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_3028}%")
# Output: Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid
# Out:
# --- Rincian Pembayaran ---
# Total Diskon  : 30% (Rp 3,600,000)
# Total Bayar   : Rp 8,400,000
# Total diskon yang Anda dapatkan: 30%

# %% [markdown]
# Penjelasan:
# 1. input total belanja, jadi angka desimal.
# 2. .strip() menghapus spasi kosong di depan/belakang teks (misal kalau user tidak sengaja ketik " y ").
# 3. .lower() mengubah semua huruf jadi huruf kecil (misal "Y" atau "YA" jadi "y"/"ya"), supaya tidak peduli besar-kecil huruf.
# 4. in ["y", "ya"] mengecek apakah teks yang diketik user ada di dalam daftar ["y", "ya"]. Hasilnya berupa True atau False, disimpan di is_member_3028.
# 5. Sama seperti di atas, tapi untuk mengecek kode promo.
# 6. Variabel penampung total diskon, dimulai dari 0%.
# 7. ni bagian kunci multi-if: tiga if terpisah, masing-masing dicek sendiri-sendiri, tidak saling menghalangi.
# += berarti "tambahkan ke nilai yang sudah ada". Jadi kalau ketiga syarat terpenuhi, diskon akan bertambah/menumpuk: 10 + 5 + 15 = 30%.
# 8. Ini beda dengan program nomor 4 tadi — di sini diskon memang dirancang untuk bisa akumulasi, sedangkan di nomor 4 empat syarat itu saling eksklusif jadi cuma satu yang jalan.
# 9. Menghitung nilai rupiah dari diskon: persen dibagi 100 dulu jadi desimal (misal 30% jadi 0.3), lalu dikali total belanja.
# 10. Total bayar = belanja awal dikurangi nominal diskon.
# 11. f adalah f-string, cara memasukkan nilai variabel langsung ke dalam teks pakai {}.
# 12. 0f adalah format angka: , menambahkan pemisah ribuan (misal 1,000,000), .0f artinya tampilkan tanpa angka desimal (dibulatkan).

# %% [markdown]
# ### 2.2.6 Program nilai_2611533028

# %%
# Buat file dengan nama nilai_2611533028.py
# Buat program untuk nested if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_3028 = int(input("Inputkan nilai angka= "))

if nilai_3028 >= 81:
    print("A")
elif nilai_3028 >= 70:
    print("B")
elif nilai_3028 >= 60:
    print("C")
elif nilai_3028 >= 50:
    print("D")
else:
    print("E")
# Out:
# A

# %% [markdown]
# Penjelasan:
# 1. Input nilai, diubah jadi angka bulat.
# 2. Ini rangkaian if / elif / elif / elif / else — berbeda dari multi-if sebelumnya karena semuanya saling berhubungan dalam satu rangkaian.
# 3. Python cek dari atas apakah nilai ≥ 81? Kalau ya, cetak "A" dan langsung berhenti, tidak mengecek elif di bawahnya lagi.
# 4. Kalau tidak (misal nilainya 75), Python lanjut cek elif nilai_3028 >= 70 → benar → cetak "B" → berhenti.
# 5. Begitu seterusnya sampai ke else di paling bawah, yang jadi "jaring pengaman" kalau semua syarat di atas gagal (nilai di bawah 50).
# 6. Contoh jalannya untuk nilai = 65:
# 65 >= 81? Tidak → lanjut.
# 65 >= 70? Tidak → lanjut.
# 65 >= 60? Ya → cetak "C" → berhenti, tidak cek lagi ke bawah.

# %% [markdown]
# ## Tugas Praktikum
#
# **Soal :**
# A. Petunjuk Pengerjaan dan Pengumpulan
# 1.        File Program Python: Buat satu file program dengan nama: tugas4_nim.py (ganti nim dengan NIM masing-masing, contoh: tugas4_2411521001.py).
# 2.        Laporan Praktikum (Jupyter Notebook): Dokumentasikan latihan praktikum serta analisis logika dan tangkapan layar eksekusi ke dalam berkas: LapPrak_ALpro4.ipynb.
# 3.        Pengumpulan GitHub: Simpan kedua file di folder Pekan4 pada repositori praktikum masing-masing (2026_PrakAlpro_[Kelas]_[NIM]). Lakukan proses add, commit, dan push sebelum batas waktu.
# 4.      Format Laporan: Wajib mengacu pada template resmi praktikum.
#
# B. Studi Kasus: Sistem Loket Terpadu & Audit Transaksi Ekspedisi Wahana
# Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional.
# Catatan Materi: Seluruh alur program disusun murni menggunakan 4 pilar percabangan yang diajarkan pada modul Pekan 4: (1) if tunggal, (2) if-else, (3) if-elif-else dengan operator logika (and, or, !=), (4) Multi-if terpisah untuk diskon akumulasi, dan (5) match-case (1 s.d. 5 beserta case _). Tidak ada nested-if (if di dalam if).
#
# C. Ketentuan Teknis dan Spesifikasi Program
# 1.        Aturan Penamaan Variabel
# Setiap variabel yang dibuat WAJIB diakhiri 4 digit NIM terakhir (contoh jika akhiran NIM 1234: umur_1234, paket_1234, total_1234). Menggunakan format snake_case.
#
# 1. Input Data Pengunjung & String Handling (Sesuai Materi Modul):
# 1)        - Program meminta: Nama Pengunjung, Umur (int), Kepemilikan SIM C / Kartu Identitas (input(...)[0] atau .strip().lower()), dan Jumlah Tiket (int).
# 2)      - Penerapan if tunggal untuk validasi kelogisan: if jumlah_tiket <= 0: program mencetak peringatan kuota tiket tidak valid.
#
# 2. Pemilihan Wahana Menggunakan match - case (Kasus Lengkap 1 - 5 dan Default _):
# 1)      Pilihan paket wahana:
# - case 1: "Wahana Safari Rimba" | Harga Satuan: Rp 50.000
# - case 2: "Wahana Arung Jeram" | Harga Satuan: Rp 75.000
# - case 3: "Wahana Motor ATV Ekstrim" | Harga Satuan: Rp 120.000
# - case 4: "Wahana Roller Coaster Kilat" | Harga Satuan: Rp 100.000
# - case 5: "Wahana All-Access VIP" | Harga Satuan: Rp 220.000
# - case _: Cetak pesan "Paket wahana tidak valid!" dan hentikan eksekusi transaksi.
#
# 3. Validasi Izin Kendali Wahana Menggunakan if - elif - else dan Operator Logika (and, !=):
# ●       Khusus untuk Paket 3 (Motor ATV Ekstrim), evaluasi izin pengendara seperti pada contoh materi slide:
# ●       - if umur >= 17 and sim == 'y':
# ●           Cetak: "Anda sudah dewasa dan boleh mengendarai ATV sendiri."
# ●       - elif umur >= 17 and sim != 'y':
# ●           Cetak: "Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)."
# ●       - elif umur < 17 and sim == 'y':
# ●           Cetak: "Identitas tidak valid: Belum cukup umur memiliki SIM."
# ●       - else:
# ●           Cetak: "Anda belum cukup umur dan tidak boleh bawa motor ATV."
# ●       *(Untuk paket selain 3, gunakan if-else sederhana untuk mengecek apakah umur >= 10 tahun)*.
#
# 4. Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah:
# Hitung subtotal = harga_satuan * jumlah_tiket.
# Gunakan serangkaian blok if independen (bukan elif) agar diskon dapat diakumulasikan (ditumpuk) sesuai materi:
# ●         if subtotal >= 200000: total_diskon_persen += 10 (Diskon Belanja Besar)
# ●         if is_member in ['y', 'ya']: total_diskon_persen += 5 (Diskon Member)
# ●         if kode_promo_valid in ['y', 'ya']: total_diskon_persen += 15 (Diskon Voucher Promo)
# ●         if jumlah_tiket >= 5: total_diskon_persen += 5 (Diskon Tambahan Rombongan)
#
# 5. Evaluasi Kelulusan Audit Menggunakan if - else:
# ●         Hitung nominal_diskon = subtotal * (total_diskon_persen / 100)
# ●         Hitung total_bayar = subtotal - nominal_diskon
# ●       Terapkan if - else untuk mengevaluasi total bayar:
# ●         if total_bayar > 300000: Cetak bonus "Selamat! Anda berhak mendapatkan Souvenir Gratis."
#  else: Cetak "Terima kasih telah berkunjung."
# ●         Tampilkan seluruh rincian pembayaran dengan f-string format desimal (:,.0f).
#
# D. Contoh Tampilan Alur Eksekusi Konsol (I/O)
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
# Masukkan Nama Pengunjung        : Ahda Amin
# Input umur anda                 : 19
# Apakah Anda Sudah Punya SIM C (y/t): y
#
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
# Masukkan nomor paket (1-5)      : 3
# Masukkan jumlah tiket           : 2
# Apakah Anda member? (y/t)       : ya
# Apakah kode promo valid? (y/t)  : ya
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.
#
# --- Rincian Pembayaran ---
# Subtotal Belanja : Rp 240,000
# Total Diskon     : 30% (Rp 72,000)
# Total Bayar      : Rp 168,000
# Catatan Layanan  : Terima kasih telah berkunjung.
# Program Selesai

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program Tugas4_2611533028

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")
nama_3028 = input("Masukkan Nama Pengunjung        : ")
umur_3028 = int(input("Input umur anda                 : "))
sim_3028 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()[0]

print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")
paket_3028 = int(input("Masukkan nomor paket (1-5)      : "))
jumlah_tiket_3028 = int(input("Masukkan jumlah tiket           : "))

# 1) if tunggal - validasi kuota tiket
if jumlah_tiket_3028 <= 0:
    print("Peringatan: Jumlah tiket tidak valid!")

# 2) match-case - pemilihan wahana (case 1-5 dan default _)
match paket_3028:
    case 1:
        nama_wahana_3028 = "Wahana Safari Rimba"
        harga_satuan_3028 = 50000
    case 2:
        nama_wahana_3028 = "Wahana Arung Jeram"
        harga_satuan_3028 = 75000
    case 3:
        nama_wahana_3028 = "Wahana Motor ATV Ekstrim"
        harga_satuan_3028 = 120000
    case 4:
        nama_wahana_3028 = "Wahana Roller Coaster Kilat"
        harga_satuan_3028 = 100000
    case 5:
        nama_wahana_3028 = "Wahana All-Access VIP"
        harga_satuan_3028 = 220000
    case _:
        print("Paket wahana tidak valid!")


# 3) if-elif-else dengan operator logika (and, !=) - validasi izin kendali wahana
if paket_3028 == 3 and umur_3028 >= 17 and sim_3028 == 'y':
    print("Anda sudah dewasa dan boleh mengendarai ATV sendiri.")
elif paket_3028 == 3 and umur_3028 >= 17 and sim_3028 != 'y':
    print("Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
elif paket_3028 == 3 and umur_3028 < 17 and sim_3028 == 'y':
    print("Identitas tidak valid: Belum cukup umur memiliki SIM.")
elif paket_3028 == 3:
    print("Anda belum cukup umur dan tidak boleh bawa motor ATV.")
elif umur_3028 >= 10:
    print("Umur memenuhi syarat untuk menaiki wahana ini.")
else:
    print("Umur belum memenuhi syarat untuk menaiki wahana ini.")

is_member_3028 = input("Apakah Anda member? (y/t)       : ").strip().lower()
kode_promo_valid_3028 = input("Apakah kode promo valid? (y/t)  : ").strip().lower()

subtotal_3028 = harga_satuan_3028 * jumlah_tiket_3028
total_diskon_persen_3028 = 0

# 4) multi-if terpisah - diskon terakumulasi (boleh saling menumpuk)
if subtotal_3028 >= 200000:
    total_diskon_persen_3028 += 10
if is_member_3028 in ['y', 'ya']:
    total_diskon_persen_3028 += 5
if kode_promo_valid_3028 in ['y', 'ya']:
    total_diskon_persen_3028 += 15
if jumlah_tiket_3028 >= 5:
    total_diskon_persen_3028 += 5

nominal_diskon_3028 = subtotal_3028 * (total_diskon_persen_3028 / 100)
total_bayar_3028 = subtotal_3028 - nominal_diskon_3028

# 5) if-else - evaluasi kelulusan audit / bonus
if total_bayar_3028 > 300000:
    print("Selamat! Anda berhak mendapatkan Souvenir Gratis.")
else:
    print("Terima kasih telah berkunjung.")

print("\n=== RINCIAN PEMBAYARAN ===")
print(f"Nama Pengunjung   : {nama_3028}")
print(f"Wahana Dipilih    : {nama_wahana_3028}")
print(f"Jumlah Tiket      : {jumlah_tiket_3028}")
print(f"Subtotal          : Rp {subtotal_3028:,.0f}")
print(f"Total Diskon      : {total_diskon_persen_3028}%")
print(f"Nominal Diskon    : Rp {nominal_diskon_3028:,.0f}")
print(f"Total Bayar       : Rp {total_bayar_3028:,.0f}")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
# Umur memenuhi syarat untuk menaiki wahana ini.
# Selamat! Anda berhak mendapatkan Souvenir Gratis.
#
# === RINCIAN PEMBAYARAN ===
# Nama Pengunjung   : KESI
# Wahana Dipilih    : Wahana All-Access VIP
# Jumlah Tiket      : 10
# Subtotal          : Rp 2,200,000
# Total Diskon      : 35%
# Nominal Diskon    : Rp 770,000
# Total Bayar       : Rp 1,430,000

# %% [markdown]
# Penjelasan:
# 1. If tunggal – if jumlah_tiket_3028 <= 0 mengecek kuota tiket; kalau nol atau minus, program mencetak peringatan tapi tetap lanjut jalan (tidak berhenti).
# 2. Match-case – match paket_3028: punya lima case (1–5) yang masing-masing mengisi nama_wahana_3028 dan harga_satuan_3028 sesuai paket yang dipilih. Ada case _ sebagai default: kalau nomor paket di luar 1–5, program mencetak "Paket wahana tidak valid!" lalu langsung sys.exit() untuk menghentikan seluruh transaksi.
# 3. If-elif-else dengan operator logika (and, !=) – satu rangkaian kondisi yang menggabungkan paket_3028 == 3 dengan umur_3028 dan sim_3028:
# umur ≥17 dan punya SIM → boleh sendiri
# umur ≥17 tanpa SIM → wajib didampingi
# umur <17 tapi punya SIM → identitas tidak valid
# umur <17 tanpa SIM → tidak boleh sama sekali
# Kalau paketnya bukan 3, kondisi jatuh ke elif umur_3028 >= 10 / else yang cuma mengecek syarat umur minimal. Semuanya tetap satu chain if-elif-else, tanpa nested-if.
# 4. Multi-if terpisah (diskon menumpuk) – empat blok if berdiri sendiri (bukan elif), jadi bisa saling menambah ke total_diskon_persen_3028: diskon belanja besar (subtotal ≥200.000), diskon member, diskon voucher promo, dan diskon rombongan (tiket ≥5).
# 5. If-else terakhir – setelah nominal_diskon_3028 dan total_bayar_3028 dihitung, kondisi total_bayar_3028 > 300000 menentukan apakah pengunjung dapat "Souvenir Gratis" atau cuma ucapan terima kasih. Semua rincian dicetak pakai f-string berformat :,.0f biar rupiahnya rapi dengan pemisah ribuan

# %% [markdown]
# <h1 align="center">BAB III<br>KESIMPULAN</h1>
# Berdasarkan enam program yang telah dibuat, dapat disimpulkan bahwa Python menyediakan beragam bentuk struktur percabangan yang masing-masing memiliki karakteristik dan kegunaan berbeda. Pernyataan if tunggal cocok digunakan untuk pengujian satu syarat sederhana, sedangkan if-else digunakan ketika terdapat dua kemungkinan hasil yang saling meniadakan.
# Struktur if-elif-else berjenjang tepat digunakan untuk kondisi yang saling eksklusif dan berurutan, seperti konversi nilai angka menjadi huruf, karena begitu satu syarat terpenuhi, pengecekan syarat berikutnya dihentikan. Sebaliknya, multi-if yang terdiri atas beberapa blok if terpisah memungkinkan setiap kondisi diperiksa secara independen, sehingga cocok digunakan pada kasus yang membutuhkan akumulasi, seperti penjumlahan persentase diskon belanja dari beberapa syarat yang terpenuhi sekaligus.
# Sementara itu, pernyataan match case terbukti memberikan alternatif penulisan kode yang lebih ringkas dan mudah dibaca dibandingkan rangkaian if-elif yang panjang, khususnya untuk kasus pencocokan terhadap sejumlah nilai tetap seperti konversi angka bulan menjadi nama bulan. Dengan memahami perbedaan mendasar antar struktur ini, seorang pemrogram dapat memilih bentuk percabangan yang paling sesuai dengan logika persoalan yang dihadapi, sehingga program yang dihasilkan lebih efisien, akurat, dan mudah dipelihara.

# %% [markdown]
# <h1 align="center">DAFTAR PUSTAKA</h1>
#
# 1. Python Software Foundation. (2024). The if statement — Compound statements. Python 3 Language Reference. https://docs.python.org/3/reference/compound_stmts.html#the-if-statement
# 2. Python Software Foundation. (2024). The match statement — Compound statements. Python 3 Language Reference. https://docs.python.org/3/reference/compound_stmts.html#the-match-statement
# 3. Van Rossum, G., Eby, T., & contributors. (2021). PEP 634 – Structural Pattern Matching: Specification. Python Enhancement Proposals. https://peps.python.org/pep-0634/
# 4. Python Software Foundation. (2024). Built-in Functions: input(), int(), float(). Python 3 Library Reference. https://docs.python.org/3/library/functions.html
# 5. Lutz, M. (2013). Learning Python (5th ed.). O'Reilly Media.
